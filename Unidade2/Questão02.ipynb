# %% [markdown]
# <a href="https://colab.research.google.com/github/HenriqueHideaki/RepositorioInteligenciaArtificial/blob/main/Unidade2/Quest%C3%A3o02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_excel("DatasetQ2_Definitivo.xlsx") 
df.drop('Paises', axis=1, inplace=True)
df.head()
# Out:
#    Expectativa de Vida  Educacao   PIB  Estabilidade Politica
# 0                 0.88      0.99  0.91                   1.10
# 1                 0.90      0.99  0.93                   1.26
# 2                 0.90      0.98  0.94                   1.24
# 3                 0.87      0.98  0.97                   1.18
# 4                 0.93      0.93  0.93                   1.20

# %%
# !pip install minisom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for minisom: filename=MiniSom-2.3.0-py3-none-any.whl size=9016 sha256=5fa814d4eacab52540ff6abf7e766d4046e51366e9dff0033ded9afbff7b7bbb
#   Stored in directory: /root/.cache/pip/wheels/6d/4e/9e/a95c14a232a196c22d9c04b221ff5d25461a1a4c55339c61db
# Successfully built minisom
# ...

# %%
X_train = df[:].values
[linha,coluna] = X_train.shape
#X_train
print(f'{linha} linhas e {coluna} coluna')
# Out:
# 21 linhas e 5 coluna

# %%
array_dataset = np.array(df)
expec_vida, educacao, pib, estab_pol = array_dataset[:,0], array_dataset[:,1], array_dataset[:,2], array_dataset[:,3]


kmeans = KMeans(n_clusters=4, random_state=0)

kmeans.fit(array_dataset)

df['K-classes'] = kmeans.labels_

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, 0, 0, 0, 0, 2, 0, 2, 1, 2, 3, 2, 1, 3, 1, 1, 3, 2, 2],
#       dtype=int32)

# %%
sb.pairplot(df,hue='K-classes')

# %%
kmeans = KMeans(n_clusters = 4, #numero de clusters
init = 'k-means++', n_init = 10, #algoritmo que define a posição dos clusters de maneira mais assertiva
max_iter = 300) #numero máximo de iterações
pred_y = kmeans.fit_predict(df)
plt.scatter(expec_vida, educacao, c = pred_y) #posicionamento dos eixos x e y
plt.scatter(pib, estab_pol, c = pred_y) #posicionamento dos eixos x e y
plt.xlim(0, 1.4) #range do eixo x
plt.ylim(0, 1.4) #range do eixo y
plt.grid() #função que desenha a grade no nosso gráfico
plt.scatter(kmeans.cluster_centers_[:,1],kmeans.cluster_centers_[:,0], s = 70, c = 'red') #posição de cada centroide no gráfico
plt.show()

# %%
plt.figure(figsize = [5,5])
plt.scatter(df[:,1],df[:,0]) 
plt.xlim(0, 1) #range do eixo x
plt.ylim(0, 1.2) #range do eixo y
plt.grid() #função que desenha a grade no nosso gráfico
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-204-c090f190895d> in <module>
#       1 plt.figure(figsize = [5,5])
# ----> 2 plt.scatter(df[:,1],df[:,0])
#       3 plt.xlim(0, 1) #range do eixo x
#       4 plt.ylim(0, 1.2) #range do eixo y
#       5 plt.grid() #função que desenha a grade no nosso gráfico
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# ...

# %%
tamanhoXdaRede = 25; 
tamanhoYdaRede = 25; 

quantidadeCaracteristicas = coluna

from minisom import MiniSom
som = MiniSom(x = tamanhoXdaRede, y = tamanhoYdaRede, input_len = quantidadeCaracteristicas, sigma = 6.0, learning_rate = 0.4)
som.pca_weights_init(X_train)

# %%
som.train_random(data = X_train, num_iteration = 800000)

# %%
import matplotlib.pyplot as plt
import numpy as np
# Obtem o vetor de pesos da rede treinada 
pesos = som.get_weights()

# %%
dataset_pesos = np.array(pesos)
#print(np.shape(dataset_pesos)), 25,25,4
plt.figure(figsize = [5,5])
plt.scatter(dataset[:,:,0],dataset[:,:,1],dataset[:,:,2], dataset[:,:,3]) 
plt.xlim(0, 1) #range do eixo x
plt.ylim(0, 1.2) #range do eixo y
plt.grid() #função que desenha a grade no nosso gráfico

# %%
import numpy as np #para manipular os vetores
from matplotlib import pyplot as plt #para plotar os gráficos
from sklearn.cluster import KMeans #para usar o KMeans

# %%
# kmeans = KMeans(n_clusters = 4, #numero de clusters
# init = 'k-means++', n_init = 10, #algoritmo que define a posição dos clusters de maneira mais assertiva
# max_iter = 300) #numero máximo de iterações
# pred_y = kmeans.fit_predict(df)
# plt.scatter(df[:,1], df[:,0], c = pred_y) #posicionamento dos eixos x e y
# plt.xlim(-75, -30) #range do eixo x
# plt.ylim(-50, 10) #range do eixo y
# plt.grid() #função que desenha a grade no nosso gráfico
# plt.scatter(kmeans.cluster_centers_[:,1],kmeans.cluster_centers_[:,0], s = 70, c = 'red') #posição de cada centroide no gráfico
# plt.show()
# Out:
#        Expectativa de Vida   Educacao        PIB  Estabilidade Politica
# count            21.000000  21.000000  21.000000              21.000000
# mean              0.688095   0.749524   0.677619               0.157619
# std               0.240263   0.249489   0.229606               1.056210
# min               0.230000   0.330000   0.270000              -1.980000
# 25%               0.470000   0.580000   0.510000              -0.680000
# 50%               0.770000   0.850000   0.690000               0.390000
# 75%               0.880000   0.930000   0.910000               1.100000
# max               0.930000   0.990000   0.970000               1.410000

# %%
# # Mostra todos os pesos 
# cont = 1;
# x = np.arange(quantidadeCaracteristicas)
# for row in pesos:
#   for elem in row:
#     plt.figure(figsize=(50,50))
#     plt.subplot(tamanhoXdaRede,tamanhoYdaRede,cont)
#     cont=cont+1
#     plt.axis([-1, 6, 0, 2])
#     plt.bar(x, elem)
#     plt.plot([-1,6],[5,5],'r')
# plt.show()
# #plt.savefig("test_som.jpg", dpi=150)

# %%
def mostraNeuronio(linha,coluna): 
  # Mostra um peso 
  x = ['Expec','Educ', 'PIB', 'Est']
  plt.plot([-1,6],[5,5],'r')
  plt.axis([-1, 4, 0, 1])
  plt.bar(x, pesos[linha,coluna,:])
  plt.show()
# Out:
# Empty DataFrame
# Columns: [Expectativa de Vida, Educacao, PIB, Estabilidade Politica]
# Index: []
