# %%
from IPython.display import Image

# %% [markdown]
# #A rede bayesiana abaixo concerne ao problema de partida de um carro, de uma forma bem simplificada (Extraído do Livro Bayesian Reasoning and Machine Learning - D. Barber)

# %% [markdown]
# ##Um agente inteligente com base nas inferências, isto é, o cálculo da P(f=empty|s=no) (a probabilidade do tanque estar vazio dado que o carro não deu partida) e da P(b=bad|s=no) (a probabilidade da bateria estar descarregada e o carro não deu partida), deve decidir qual o problema mais provável pela não partida do carro. Apresente a solução e implemente os cálculos de forma computacional

# %%
Image('/content/DIAGRAMA.jpeg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\display.py:1032, in Image._data_and_metadata(self, always_both)
#    1031 try:
# -> 1032     b64_data = b2a_base64(self.data).decode('ascii')
#    1033 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:973, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     970     method = get_real_method(obj, self.print_method)
#     972     if method is not None:
# --> 973         return method(include=include, exclude=exclude)
#     974     return None
#     975 else:
#
# File ~\anaconda3\lib\site-packages\IPython\core\display.py:1022, in Image._repr_mimebundle_(self, include, exclude)
#    1020 if self.embed:
#    1021     mimetype = self._mimetype
# -> 1022     data, metadata = self._data_and_metadata(always_both=True)
#    1023     if metadata:
#    1024         metadata = {mimetype: metadata}
#
# File ~\anaconda3\lib\site-packages\IPython\core\display.py:1034, in Image._data_and_metadata(self, always_both)
#    1032     b64_data = b2a_base64(self.data).decode('ascii')
#    1033 except TypeError as e:
# -> 1034     raise FileNotFoundError(
#    1035         "No such file or directory: '%s'" % (self.data)) from e
#    1036 md = {}
#    1037 if self.metadata:
#
# FileNotFoundError: No such file or directory: '/content/DIAGRAMA.jpeg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\display.py:1032, in Image._data_and_metadata(self, always_both)
#    1031 try:
# -> 1032     b64_data = b2a_base64(self.data).decode('ascii')
#    1033 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~\anaconda3\lib\site-packages\IPython\core\display.py:1054, in Image._repr_png_(self)
#    1052 def _repr_png_(self):
#    1053     if self.embed and self.format == self._FMT_PNG:
# -> 1054         return self._data_and_metadata()
#
# File ~\anaconda3\lib\site-packages\IPython\core\display.py:1034, in Image._data_and_metadata(self, always_both)
#    1032     b64_data = b2a_base64(self.data).decode('ascii')
#    1033 except TypeError as e:
# -> 1034     raise FileNotFoundError(
#    1035         "No such file or directory: '%s'" % (self.data)) from e
#    1036 md = {}
#    1037 if self.metadata:
#
# FileNotFoundError: No such file or directory: '/content/DIAGRAMA.jpeg'

# %%
# !pip install pgmpy
# Out:
# Requirement already satisfied: pgmpy in c:\users\hidea\anaconda3\lib\site-packages (0.1.19)
# Requirement already satisfied: networkx in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (2.7.1)
# Requirement already satisfied: scipy in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (1.7.3)
# Requirement already satisfied: statsmodels in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (0.13.2)
# Requirement already satisfied: numpy in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (1.21.5)
# Requirement already satisfied: pandas in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: pyparsing in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (3.0.4)
# Requirement already satisfied: joblib in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (1.1.0)
# Requirement already satisfied: torch in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (1.12.1)
# Requirement already satisfied: tqdm in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (4.64.0)
# Requirement already satisfied: scikit-learn in c:\users\hidea\anaconda3\lib\site-packages (from pgmpy) (1.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hidea\anaconda3\lib\site-packages (from pandas->pgmpy) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hidea\anaconda3\lib\site-packages (from pandas->pgmpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hidea\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pgmpy) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hidea\anaconda3\lib\site-packages (from scikit-learn->pgmpy) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hidea\anaconda3\lib\site-packages (from statsmodels->pgmpy) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\hidea\anaconda3\lib\site-packages (from statsmodels->pgmpy) (21.3)
# Requirement already satisfied: typing-extensions in c:\users\hidea\anaconda3\lib\site-packages (from torch->pgmpy) (4.1.1)
# Requirement already satisfied: colorama in c:\users\hidea\anaconda3\lib\site-packages (from tqdm->pgmpy) (0.4.4)

# %%
from pgmpy.models import BayesianModel
from pgmpy.factors.discrete import TabularCPD

# Definindo a estrutura do modelo
model = BayesianModel([('B', 'G'), ('B', 'T'), ('T', 'S'), ('F', 'G'), ('F','S') ])

cpd_b = TabularCPD(variable='B', variable_card=2, values=[[0.95], [0.05]], state_names = { 'B': ['GOOD', 'BAD'] })
cpd_f = TabularCPD(variable='F', variable_card=2, values=[[0.1], [0.9]], state_names = { 'F': ['EMPTY', 'NOT EMPTY'] })
cpd_g = TabularCPD(variable='G', variable_card=2, values = [[0.98,0.05,0.97,0.07],
                                                            [0.02,0.95,0.03,0.93]],
                   evidence=['B', 'F'],
                   evidence_card=[2, 2], 
                   state_names = { 'G': ['EMPTY', 'NOT EMPTY'], 'B': ['GOOD', 'BAD'], 'F': ['EMPTY', 'NOT EMPTY']}
)
cpd_t = TabularCPD(variable='T', variable_card=2, values = [[0.1,0.96],
                                                            [0.9,0.04]],
                   evidence=['B'],
                   evidence_card=[2], 
                   state_names = { 'T': ['FALSE', 'TRUE'], 'B': ['GOOD', 'BAD']}
)
cpd_s = TabularCPD(variable='S', variable_card=2, values = [[0.99,1,0.92,0.01],
                                                            [0.01,0,0.08,0.99]],
                   evidence=['T', 'F'],
                   evidence_card=[2,2], 
                   state_names = { 'S': ['FALSE', 'TRUE'], 'T': ['FALSE', 'TRUE'], 'F': ['EMPTY', 'NOT EMPTY']}
)


model.add_cpds(cpd_b,cpd_f,cpd_g,cpd_t,cpd_s)
model.check_model()
# Out:
# C:\Users\Hidea\anaconda3\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(
# True

# %%
# Agora podemos chamar alguns métodos no objeto BayesianModel.
model.get_cpds()
# Out:
# [<TabularCPD representing P(B:2) at 0x2858f262e20>,
#  <TabularCPD representing P(F:2) at 0x285865ce430>,
#  <TabularCPD representing P(G:2 | B:2, F:2) at 0x2858f262340>,
#  <TabularCPD representing P(T:2 | B:2) at 0x2858f262280>,
#  <TabularCPD representing P(S:2 | T:2, F:2) at 0x2858f2622b0>]

# %%
print('Battery')
print(cpd_b)
print('\nFuel')
print(cpd_f)
print('\nGauge')
print(cpd_g)
print('\nTurn Over')
print(cpd_t)
print('\nStart')
print(cpd_s)
# Out:
# Battery
# +---------+------+
# | B(GOOD) | 0.95 |
# +---------+------+
# | B(BAD)  | 0.05 |
# +---------+------+
#
# Fuel
# +--------------+-----+
# | F(EMPTY)     | 0.1 |
# +--------------+-----+
# | F(NOT EMPTY) | 0.9 |
# +--------------+-----+
#
# Gauge
# +--------------+----------+--------------+----------+--------------+
# | B            | B(GOOD)  | B(GOOD)      | B(BAD)   | B(BAD)       |
# +--------------+----------+--------------+----------+--------------+
# | F            | F(EMPTY) | F(NOT EMPTY) | F(EMPTY) | F(NOT EMPTY) |
# +--------------+----------+--------------+----------+--------------+
# | G(EMPTY)     | 0.98     | 0.05         | 0.97     | 0.07         |
# +--------------+----------+--------------+----------+--------------+
# | G(NOT EMPTY) | 0.02     | 0.95         | 0.03     | 0.93         |
# +--------------+----------+--------------+----------+--------------+
#
# Turn Over
# +----------+---------+--------+
# | B        | B(GOOD) | B(BAD) |
# +----------+---------+--------+
# | T(FALSE) | 0.1     | 0.96   |
# +----------+---------+--------+
# | T(TRUE)  | 0.9     | 0.04   |
# +----------+---------+--------+
#
# Start
# +----------+----------+--------------+----------+--------------+
# | T        | T(FALSE) | T(FALSE)     | T(TRUE)  | T(TRUE)      |
# +----------+----------+--------------+----------+--------------+
# | F        | F(EMPTY) | F(NOT EMPTY) | F(EMPTY) | F(NOT EMPTY) |
# +----------+----------+--------------+----------+--------------+
# | S(FALSE) | 0.99     | 1.0          | 0.92     | 0.01         |
# +----------+----------+--------------+----------+--------------+
# | S(TRUE)  | 0.01     | 0.0          | 0.08     | 0.99         |
# +----------+----------+--------------+----------+--------------+

# %% [markdown]
# #o cálculo da P(f=empty|s=no) (a probabilidade do tanque estar vazio dado que o carro não deu partida) e da P(b=bad|s=no) (a probabilidade da bateria estar descarregada e o carro não deu partida), deve decidir qual o problema mais provável pela não partida do carro.

# %%
from pgmpy.inference import VariableElimination
infer = VariableElimination(model)

t_dist = infer.query(['T'])
b_dist = infer.query(['S'])
s_dist = infer.query(['B'])


print(infer.query(['F'], evidence={'S': 'FALSE'}))
print(infer.query(['B'], evidence={'S': 'FALSE'}))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# +--------------+----------+
# | F            |   phi(F) |
# +==============+==========+
# | F(EMPTY)     |   0.4054 |
# +--------------+----------+
# | F(NOT EMPTY) |   0.5946 |
# +--------------+----------+
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# +---------+----------+
# | B       |   phi(B) |
# +=========+==========+
# | B(GOOD) |   0.7901 |
# +---------+----------+
# | B(BAD)  |   0.2099 |
# +---------+----------+

# %% [markdown]
# # A probabilidade do tanque estar vazio dado que o carro não deu partida é 40,54% enquanto que a probabilidade da bateria estar descarregada dado que o carro também não deu a partida é de 20,99%, podemos inferir então que é mais provavel que o motivo do carro não ter dado a partida é que o tanque esteja vazio.
